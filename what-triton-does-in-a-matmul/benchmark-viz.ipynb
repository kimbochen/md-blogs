# %%
import torch
from matmul import benchmark_main

# %%
benchmark_main(torch.float32)
# Out:
# Triton autotuning for function matmul_kernel finished after 3.01s; best config selected: B_M: 128, B_N: 32, B_K: 32, num_warps: 4, num_ctas: 1, num_stages: 4;
# Matmul Performance:
#          M       N       K     cuBLAS     Triton
# 0    256.0   256.0   256.0   2.978909   3.276800
# 1    384.0   384.0   384.0   7.372800   8.346566
# 2    512.0   512.0   512.0  11.397565  12.483048
# 3    640.0   640.0   640.0  11.906977  17.655172
# 4    768.0   768.0   768.0  17.014154  26.021647
# 5    896.0   896.0   896.0  16.675703  20.886268
# 6   1024.0  1024.0  1024.0  19.418074  27.235741
# 7   1152.0  1152.0  1152.0  21.955764  34.321655
# 8   1280.0  1280.0  1280.0  18.450450  26.425806
# 9   1408.0  1408.0  1408.0  20.495399  31.473359
# 10  1536.0  1536.0  1536.0  22.541044  31.043368
# 11  1664.0  1664.0  1664.0  17.784411  27.105157
# 12  1792.0  1792.0  1792.0  19.928057  30.541912
# 13  1920.0  1920.0  1920.0  20.632836  32.450703
# 14  2048.0  2048.0  2048.0  20.560314  28.826831
# ...

# %%
benchmark_main(torch.float16)
# Out:
# Matmul Performance:
#          M       N       K     cuBLAS     Triton
# 0    256.0   256.0   256.0   5.461333   4.681143
# 1    384.0   384.0   384.0  12.288000  12.288000
# 2    512.0   512.0   512.0  26.214401  26.214401
# 3    640.0   640.0   640.0  23.272727  30.117647
# 4    768.0   768.0   768.0  44.236801  46.565055
# 5    896.0   896.0   896.0  39.025776  43.904000
# 6   1024.0  1024.0  1024.0  51.150050  49.932191
# 7   1152.0  1152.0  1152.0  63.658552  63.531573
# 8   1280.0  1280.0  1280.0  67.948159  56.888887
# 9   1408.0  1408.0  1408.0  46.596375  63.392744
# 10  1536.0  1536.0  1536.0  63.728872  60.494768
# 11  1664.0  1664.0  1664.0  50.555685  55.208048
# 12  1792.0  1792.0  1792.0  62.441243  62.096267
# 13  1920.0  1920.0  1920.0  64.000000  63.645494
# 14  2048.0  2048.0  2048.0  63.072243  59.074702
# 15  2176.0  2176.0  2176.0  64.914993  61.352586
# 16  2304.0  2304.0  2304.0  72.607513  67.100763
# 17  2432.0  2432.0  2432.0  55.087186  63.275819
# ...

# %%
benchmark_main(torch.bfloat16)
# Out:
# Matmul Performance:
#          M       N       K     cuBLAS     Triton
# 0    256.0   256.0   256.0   4.681143   4.681143
# 1    384.0   384.0   384.0  12.288000  13.507421
# 2    512.0   512.0   512.0  26.214401  26.214401
# 3    640.0   640.0   640.0  24.380953  31.568401
# 4    768.0   768.0   768.0  46.565055  46.565055
# 5    896.0   896.0   896.0  37.971025  45.320259
# 6   1024.0  1024.0  1024.0  49.932191  49.932191
# 7   1152.0  1152.0  1152.0  60.725446  63.531573
# 8   1280.0  1280.0  1280.0  52.512822  56.888887
# 9   1408.0  1408.0  1408.0  63.392744  63.392744
# 10  1536.0  1536.0  1536.0  63.195428  60.494768
# 11  1664.0  1664.0  1664.0  38.788413  55.893862
# 12  1792.0  1792.0  1792.0  63.499573  62.790080
# 13  1920.0  1920.0  1920.0  64.000000  63.705071
# 14  2048.0  2048.0  2048.0  62.836016  59.283449
# 15  2176.0  2176.0  2176.0  65.125075  61.806002
# 16  2304.0  2304.0  2304.0  72.828879  67.863272
# 17  2432.0  2432.0  2432.0  65.794999  64.010170
# ...

# %%
from matmul import test_correctness

# %%
test_correctness(4096)
# Out:
# Triton autotuning for function matmul_kernel finished after 1.29s; best config selected: B_M: 128, B_N: 128, B_K: 32, num_warps: 4, num_ctas: 1, num_stages: 4;
# True
